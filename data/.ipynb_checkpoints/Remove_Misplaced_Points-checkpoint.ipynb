# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon

# Importing and plotting the cities shapefile
df = pd.read_csv('shapes_europe/hermes_file.csv')
gdf = gpd.read_file("shapes_europe/Europe.shp")
gdf.plot(cmap='OrRd', figsize = (15,10))
plt.xlim(xmax = -6, xmin = -10)
plt.ylim(ymax = 42.5, ymin = 36.5)

# Changes the MULTIPOLYGON to Polygons
gs = gdf.explode()
gs_portugal = gs.loc[gs['ORGN_NAME'] == 'Portugal',:]

#Locate just Portugal
gs_portugal_part = gs_portugal.iloc[34:35,:]
gs_portugal_shape = gs_portugal_part['geometry'][0]
display(gs_portugal_shape)

#Function to remove missplaced points
def drop_missplaced_points(df):
    drop_rows = []
    for i in range(df.shape[0]):
        #print(i)
        inside_region = Point(df['Longitude'][i], df['Latitude'][i]).within(gs_portugal_shape)
        #inside_region = True
        if (inside_region == False):
            drop_rows.append(i)
    df = df.drop(drop_rows)
    return df

df = drop_missplaced_points(df)
df.shape
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4,5,7,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (32367, 30)

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Concelho Code DICOFRE  \
# 0               0           0.0             0.0         1010.0   10103
# 1               0           0.0             0.0         1010.0   10103
# 2               0           0.0             0.0         1010.0   10103
# 3               0           0.0             0.0         1010.0   10103
# 4               0           0.0             0.0         1010.0   10103
# ...           ...           ...             ...            ...     ...
# 34202        2975           NaN             NaN            NaN     NaN
# 34203        2975           NaN             NaN            NaN     NaN
# 34204        2975           NaN             NaN            NaN     NaN
# 34205        2975           NaN             NaN            NaN     NaN
# 34206        2975           NaN             NaN            NaN     NaN
#
#         NUTSI_DSG  NUTSI_COD NUTSII_DSG  NUTSII_COD       NUTSIII_DSG  ...  \
# 0      CONTINENTE        1.0     CENTRO        16.0  REGIÃO DE AVEIRO  ...
# 1      CONTINENTE        1.0     CENTRO        16.0  REGIÃO DE AVEIRO  ...
# 2      CONTINENTE        1.0     CENTRO        16.0  REGIÃO DE AVEIRO  ...
# 3      CONTINENTE        1.0     CENTRO        16.0  REGIÃO DE AVEIRO  ...
# 4      CONTINENTE        1.0     CENTRO        16.0  REGIÃO DE AVEIRO  ...
# ...           ...        ...        ...         ...               ...  ...
# 34202         NaN        NaN        NaN         NaN               NaN  ...
# 34203         NaN        NaN        NaN         NaN               NaN  ...
# 34204         NaN        NaN        NaN         NaN               NaN  ...
# 34205         NaN        NaN        NaN         NaN               NaN  ...
# 34206         NaN        NaN        NaN         NaN               NaN  ...
#
#       Diferença   Latitude Longitude    20/Mar    21/Mar    22/Mar    23/Mar  \
# 0      2.172589  40.497445 -8.389415  0.000356  0.000506  0.000716  0.001013
# 1      2.172589  40.539149 -8.398416  0.000356  0.000506  0.000716  0.001013
# 2      2.172589  40.522047 -8.416118  0.000356  0.000506  0.000716  0.001013
# 3      2.172589  40.536749 -8.409217  0.000356  0.000506  0.000716  0.001013
# 4      2.172589  40.529548 -8.426019  0.000356  0.000506  0.000716  0.001013
# ...         ...        ...       ...       ...       ...       ...       ...
# 34202       NaN  38.748590 -9.160670       NaN       NaN       NaN       NaN
# 34203       NaN  38.748590 -9.160670       NaN       NaN       NaN       NaN
# 34204       NaN  38.748590 -9.160670       NaN       NaN       NaN       NaN
# 34205       NaN  38.748590 -9.160670       NaN       NaN       NaN       NaN
# 34206       NaN  38.748590 -9.160670       NaN       NaN       NaN       NaN
#
#          24/Mar     rand1     rand2
# 0      0.001429  0.026403 -0.019502
# 1      0.001429  0.017402  0.022202
# 2      0.001429 -0.000300  0.005101
# 3      0.001429  0.006601  0.019802
# 4      0.001429 -0.010201  0.012601
# ...         ...       ...       ...
# 34202       NaN  0.000000  0.000000
# 34203       NaN  0.000000  0.000000
# 34204       NaN  0.000000  0.000000
# 34205       NaN  0.000000  0.000000
# 34206       NaN  0.000000  0.000000
#
# [32367 rows x 30 columns]
